# %% [markdown]
# <a href="https://colab.research.google.com/github/Amrinnridegreecollege/Python-mini-project-/blob/main/Pandas_Basics6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
age=[]
height=[]
weight=[]
speed=[]
for _ in range(100):
 age.append(random.randint(0,100))
 height.append(random.randint(0,100))
 weight.append(random.randint(0,100))
 speed.append(random.randint(0,100))
idata={'age':age,'height':height,'weight':weight,'speed':speed}

# %%
idata
# Out:
# {'age': [52,
#   18,
#   97,
#   81,
#   26,
#   30,
#   97,
#   54,
#   91,
#   17,
#   77,
#   6,
#   5,
#   74,
#   31,
#   93,
#   5,
#   44,
#   90,
#   100,
#   27,
#   36,
#   33,
#   3,
#   27,
#   66,
#   23,
#   85,
#   54,
#   11,
#   95,
#   3,
#   19,
#   79,
#   61,
#   33,
#   32,
#   38,
#   39,
#   62,
#   41,
#   76,
#   32,
#   76,
#   100,
#   5,
#   100,
#   13,
#   28,
#   75,
#   60,
#   65,
#   0,
#   61,
#   18,
#   39,
#   42,
#   46,
#   83,
#   29,
#   12,
#   65,
#   59,
#   94,
#   60,
#   57,
#   7,
#   10,
#   76,
#   72,
#   2,
#   36,
#   6,
#   42,
#   64,
#   35,
#   61,
#   24,
#   13,
#   21,
#   58,
#   45,
#   39,
#   94,
#   63,
#   48,
#   48,
#   52,
#   82,
#   28,
#   73,
#   97,
#   97,
#   62,
#   62,
#   22,
#   63,
#   6,
#   92,
#   66],
#  'height': [79,
#   7,
#   10,
#   23,
#   66,
#   21,
#   99,
#   43,
#   6,
#   53,
#   40,
#   13,
#   48,
#   61,
#   53,
#   100,
#   76,
#   47,
#   24,
#   12,
#   4,
#   30,
#   62,
#   8,
#   36,
#   60,
#   2,
#   58,
#   13,
#   64,
#   30,
#   77,
#   92,
#   33,
#   40,
#   91,
#   56,
#   56,
#   0,
#   31,
#   28,
#   78,
#   22,
#   79,
#   1,
#   43,
#   12,
#   54,
#   42,
#   69,
#   22,
#   75,
#   22,
#   12,
#   84,
#   79,
#   17,
#   95,
#   60,
#   68,
#   42,
#   41,
#   3,
#   70,
#   40,
#   32,
#   70,
#   58,
#   77,
#   71,
#   28,
#   34,
#   53,
#   66,
#   29,
#   53,
#   0,
#   1,
#   29,
#   60,
#   34,
#   90,
#   100,
#   87,
#   41,
#   16,
#   61,
#   6,
#   34,
#   31,
#   33,
#   6,
#   37,
#   64,
#   4,
#   9,
#   39,
#   74,
#   14,
#   2],
#  'weight': [49,
#   87,
#   16,
#   5,
#   12,
#   48,
#   15,
#   82,
#   63,
#   55,
#   66,
#   60,
#   44,
#   81,
#   50,
#   31,
#   98,
#   20,
#   52,
#   57,
#   33,
#   94,
#   99,
#   6,
#   23,
#   45,
#   98,
#   11,
#   39,
#   21,
#   64,
#   81,
#   24,
#   39,
#   41,
#   91,
#   63,
#   58,
#   53,
#   43,
#   78,
#   11,
#   66,
#   57,
#   37,
#   30,
#   75,
#   40,
#   40,
#   53,
#   74,
#   94,
#   53,
#   6,
#   17,
#   99,
#   26,
#   58,
#   50,
#   31,
#   47,
#   25,
#   48,
#   23,
#   98,
#   74,
#   5,
#   2,
#   42,
#   73,
#   6,
#   95,
#   1,
#   53,
#   48,
#   41,
#   27,
#   55,
#   13,
#   83,
#   71,
#   1,
#   27,
#   84,
#   31,
#   33,
#   57,
#   97,
#   49,
#   2,
#   37,
#   0,
#   98,
#   7,
#   69,
#   60,
#   33,
#   35,
#   37,
#   80],
#  'speed': [96,
#   43,
#   55,
#   37,
#   59,
#   80,
#   49,
#   49,
#   1,
#   55,
#   5,
#   28,
#   86,
#   84,
#   13,
#   6,
#   48,
#   55,
#   88,
#   13,
#   87,
#   40,
#   41,
#   19,
#   57,
#   94,
#   48,
#   82,
#   52,
#   53,
#   44,
#   4,
#   56,
#   48,
#   41,
#   0,
#   68,
#   16,
#   71,
#   96,
#   70,
#   13,
#   70,
#   82,
#   81,
#   14,
#   16,
#   92,
#   93,
#   50,
#   92,
#   40,
#   75,
#   7,
#   59,
#   100,
#   93,
#   37,
#   46,
#   37,
#   58,
#   4,
#   85,
#   52,
#   89,
#   10,
#   58,
#   31,
#   13,
#   86,
#   1,
#   65,
#   37,
#   34,
#   90,
#   14,
#   67,
#   52,
#   13,
#   67,
#   1,
#   53,
#   63,
#   39,
#   84,
#   57,
#   43,
#   29,
#   4,
#   29,
#   9,
#   66,
#   17,
#   66,
#   29,
#   46,
#   28,
#   10,
#   58,
#   26]}

# %%
df1=pd.DataFrame(idata)

# %%
df1.describe()
# Out:
#               age     height      weight       speed
# count  100.000000  100.00000  100.000000  100.000000
# mean    49.160000   43.25000   47.790000   48.170000
# std     29.426409   28.04051   28.291161   28.632487
# min      0.000000    0.00000    0.000000    0.000000
# 25%     26.750000   21.75000   26.750000   27.500000
# 50%     48.000000   40.50000   48.000000   49.000000
# 75%     73.250000   64.50000   66.750000   68.500000
# max    100.000000  100.00000   99.000000  100.000000

# %%
df1[['age','height']]
# Out:
#     age  height
# 0    52      79
# 1    18       7
# 2    97      10
# 3    81      23
# 4    26      66
# ..  ...     ...
# 95   22       9
# 96   63      39
# 97    6      74
# 98   92      14
# 99   66       2
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['age','height']]
# Out:
#    age  height
# 0   52      79
# 3   81      23

# %%
df2 = df1[['age','height']]

# %%
df1.sort_index(ascending=False)
# Out:
#     age  height  weight  speed
# 99   66       2      80     26
# 98   92      14      37     58
# 97    6      74      35     10
# 96   63      39      33     28
# 95   22       9      60     46
# ..  ...     ...     ...    ...
# 4    26      66      12     59
# 3    81      23       5     37
# 2    97      10      16     55
# 1    18       7      87     43
# 0    52      79      49     96
#
# [100 rows x 4 columns]

# %%
df1[0::2].describe()
# Out:
#               age      height     weight      speed
# count   50.000000   50.000000  50.000000  50.000000
# mean    50.440000   38.280000  47.240000  52.140000
# std     30.636886   27.192466  25.829551  29.200231
# min      0.000000    0.000000   1.000000   1.000000
# 25%     27.000000   18.250000  28.000000  31.000000
# 50%     53.000000   35.000000  47.500000  56.500000
# 75%     75.250000   55.250000  63.750000  74.000000
# max    100.000000  100.000000  99.000000  96.000000

# %%
#filter
df1['weight']>50
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 95     True
# 96    False
# 97    False
# 98    False
# 99     True
# Name: weight, Length: 100, dtype: bool

# %%
#filter
filter1 = df1['weight']>50

# %%
df1[filter1]
# Out:
#     age  height  weight  speed
# 1    18       7      87     43
# 7    54      43      82     49
# 8    91       6      63      1
# 9    17      53      55     55
# 10   77      40      66      5
# 11    6      13      60     28
# 13   74      61      81     84
# 16    5      76      98     48
# 18   90      24      52     88
# 19  100      12      57     13
# 21   36      30      94     40
# 22   33      62      99     41
# 26   23       2      98     48
# 30   95      30      64     44
# 31    3      77      81      4
# 35   33      91      91      0
# 36   32      56      63     68
# 37   38      56      58     16
# 38   39       0      53     71
# 40   41      28      78     70
# 42   32      22      66     70
# 43   76      79      57     82
# 46  100      12      75     16
# 49   75      69      53     50
# 50   60      22      74     92
# 51   65      75      94     40
# 52    0      22      53     75
# 55   39      79      99    100
# 57   46      95      58     37
# 64   60      40      98     89
# 65   57      32      74     10
# 69   72      71      73     86
# 71   36      34      95     65
# 73   42      66      53     34
# 77   24       1      55     52
# 79   21      60      83     67
# 80   58      34      71      1
# 83   94      87      84     39
# 86   48      61      57     43
# 87   52       6      97     29
# 92   97      37      98     17
# 94   62       4      69     29
# 95   22       9      60     46
# 99   66       2      80     26

# %%
df1.loc[filter1]
# Out:
#     age  height  weight  speed
# 1    18       7      87     43
# 7    54      43      82     49
# 8    91       6      63      1
# 9    17      53      55     55
# 10   77      40      66      5
# 11    6      13      60     28
# 13   74      61      81     84
# 16    5      76      98     48
# 18   90      24      52     88
# 19  100      12      57     13
# 21   36      30      94     40
# 22   33      62      99     41
# 26   23       2      98     48
# 30   95      30      64     44
# 31    3      77      81      4
# 35   33      91      91      0
# 36   32      56      63     68
# 37   38      56      58     16
# 38   39       0      53     71
# 40   41      28      78     70
# 42   32      22      66     70
# 43   76      79      57     82
# 46  100      12      75     16
# 49   75      69      53     50
# 50   60      22      74     92
# 51   65      75      94     40
# 52    0      22      53     75
# 55   39      79      99    100
# 57   46      95      58     37
# 64   60      40      98     89
# 65   57      32      74     10
# 69   72      71      73     86
# 71   36      34      95     65
# 73   42      66      53     34
# 77   24       1      55     52
# 79   21      60      83     67
# 80   58      34      71      1
# 83   94      87      84     39
# 86   48      61      57     43
# 87   52       6      97     29
# 92   97      37      98     17
# 94   62       4      69     29
# 95   22       9      60     46
# 99   66       2      80     26

# %%
filter2 = df1['age']>50

# %%
df1[filter1 &filter2]
# Out:
#     age  height  weight  speed
# 7    54      43      82     49
# 8    91       6      63      1
# 10   77      40      66      5
# 13   74      61      81     84
# 18   90      24      52     88
# 19  100      12      57     13
# 30   95      30      64     44
# 43   76      79      57     82
# 46  100      12      75     16
# 49   75      69      53     50
# 50   60      22      74     92
# 51   65      75      94     40
# 64   60      40      98     89
# 65   57      32      74     10
# 69   72      71      73     86
# 80   58      34      71      1
# 83   94      87      84     39
# 87   52       6      97     29
# 92   97      37      98     17
# 94   62       4      69     29
# 99   66       2      80     26

# %%
df1.loc[filter1 &filter2]
# Out:
#     age  height  weight  speed
# 7    54      43      82     49
# 8    91       6      63      1
# 10   77      40      66      5
# 13   74      61      81     84
# 18   90      24      52     88
# 19  100      12      57     13
# 30   95      30      64     44
# 43   76      79      57     82
# 46  100      12      75     16
# 49   75      69      53     50
# 50   60      22      74     92
# 51   65      75      94     40
# 64   60      40      98     89
# 65   57      32      74     10
# 69   72      71      73     86
# 80   58      34      71      1
# 83   94      87      84     39
# 87   52       6      97     29
# 92   97      37      98     17
# 94   62       4      69     29
# 99   66       2      80     26
